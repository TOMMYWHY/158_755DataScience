# %% [markdown]
# # Data Wrangling

# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.pyplot import GridSpec
import numpy as np
import pandas as pd
import os, sys
import seaborn as sns
sns.set(style="ticks")
from pylab import rcParams
rcParams['figure.figsize'] = 7,5
rcParams['figure.dpi'] = 120
rcParams['font.size'] = 20
rcParams['axes.facecolor'] = 'white'
matplotlib.style.use('ggplot')
import statsmodels.formula.api as smf
import statsmodels.api as sm
import missingno as msno
import sklearn
# %matplotlib inline

# %% [markdown]
# ### loading player stats data

# %%
players = pd.read_csv("stats.csv.gz",index_col=0)
print(players.shape)
players.head()
# Out:
# (649, 29)
#                      Player Pos   Age   Tm     G    GS      MP     FG    FGA  \
# 0              Steven Adams   C  26.0  OKC  58.0  58.0  1564.0  262.0  443.0
# 1               Bam Adebayo  PF  22.0  MIA  65.0  65.0  2235.0  408.0  719.0
# 2         LaMarcus Aldridge   C  34.0  SAS  53.0  53.0  1754.0  391.0  793.0
# 3  Nickeil Alexander-Walker  SG  21.0  NOP  41.0   0.0   501.0   77.0  227.0
# 4             Grayson Allen  SG  24.0  MEM  30.0   0.0   498.0   79.0  176.0
#
#      FG%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK    TOV     PF  \
# 0  0.591  ...  0.590  196.0  347.0  543.0  141.0  50.0  65.0   86.0  111.0
# 1  0.567  ...  0.690  165.0  518.0  683.0  333.0  78.0  85.0  185.0  164.0
# 2  0.493  ...  0.827  103.0  289.0  392.0  129.0  36.0  87.0   74.0  128.0
# 3  0.339  ...  0.607    8.0   72.0   80.0   74.0  11.0   7.0   40.0   46.0
# 4  0.449  ...  0.857    5.0   61.0   66.0   43.0   6.0   1.0   23.0   36.0
#
#       PTS
# 0   633.0
# 1  1053.0
# 2  1001.0
# 3   211.0
# 4   221.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### loading salary data

# %%
raw_salary = pd.read_csv("salary.csv.gz",index_col=0)
print(raw_salary.shape)
raw_salary.head()
# Out:
# (564, 4)
#   RK                   NAME                   TEAM       SALARY
# 0  1      Stephen Curry, PG  Golden State Warriors  $40,231,758
# 1  2         Chris Paul, PG  Oklahoma City Thunder  $38,506,482
# 2  3  Russell Westbrook, PG        Houston Rockets  $38,506,482
# 3  4          John Wall, PG     Washington Wizards  $38,199,000
# 4  5       Kevin Durant, SF          Brooklyn Nets  $38,199,000

# %% [markdown]
# ### I  just need player name and salary for this report. The salary formate need change to normal numbers

# %%
raw_salary['full-name'], raw_salary['Position'] = raw_salary['NAME'].str.split(',', 1).str
raw_salary.head()
# Out:
#   RK                   NAME                   TEAM       SALARY  \
# 0  1      Stephen Curry, PG  Golden State Warriors  $40,231,758
# 1  2         Chris Paul, PG  Oklahoma City Thunder  $38,506,482
# 2  3  Russell Westbrook, PG        Houston Rockets  $38,506,482
# 3  4          John Wall, PG     Washington Wizards  $38,199,000
# 4  5       Kevin Durant, SF          Brooklyn Nets  $38,199,000
#
#            full-name Position
# 0      Stephen Curry       PG
# 1         Chris Paul       PG
# 2  Russell Westbrook       PG
# 3          John Wall       PG
# 4       Kevin Durant       SF

# %%
def covert_currency(x): #1change salary formate
    if x == 0:
        return 0
    else:
        return x.replace("$","").replace(",","")
    
cust_str = raw_salary['SALARY'].apply(lambda x:covert_currency(x)) #2

raw_salary['SALARY'] = pd.to_numeric(cust_str, errors='coerce')

# %%
salary = raw_salary[['full-name','SALARY','Position']]

# %%
salary = salary.rename(columns={'full-name':'Player','SALARY':'Salary'})
print(salary.shape)
salary.head()
# Out:
# (564, 3)
#               Player      Salary Position
# 0      Stephen Curry  40231758.0       PG
# 1         Chris Paul  38506482.0       PG
# 2  Russell Westbrook  38506482.0       PG
# 3          John Wall  38199000.0       PG
# 4       Kevin Durant  38199000.0       SF

# %% [markdown]
# ## merging

# %% [markdown]
# ### merging and concatenation 2 datasets

# %%
df = pd.merge(salary,players,on="Player",how='outer')
print(df.shape)
df.head()
# Out:
# (807, 31)
#               Player      Salary Position  Pos   Age   Tm     G    GS      MP  \
# 0      Stephen Curry  40231758.0       PG   PG  31.0  GSW   5.0   5.0   139.0
# 1         Chris Paul  38506482.0       PG   PG  34.0  OKC  63.0  63.0  2003.0
# 2  Russell Westbrook  38506482.0       PG   PG  31.0  HOU  53.0  53.0  1905.0
# 3          John Wall  38199000.0       PG  NaN   NaN  NaN   NaN   NaN     NaN
# 4       Kevin Durant  38199000.0       SF  NaN   NaN  NaN   NaN   NaN     NaN
#
#       FG  ...    FT%   ORB    DRB    TRB    AST   STL   BLK    TOV     PF  \
# 0   33.0  ...  1.000   4.0   22.0   26.0   33.0   5.0   2.0   16.0   11.0
# 1  394.0  ...  0.900  21.0  289.0  310.0  426.0  98.0   9.0  137.0  139.0
# 2  568.0  ...  0.777  94.0  332.0  426.0  370.0  88.0  17.0  236.0  187.0
# 3    NaN  ...    NaN   NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 4    NaN  ...    NaN   NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#       PTS
# 0   104.0
# 1  1114.0
# 2  1456.0
# 3     NaN
# 4     NaN
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Player', 'Salary', 'Position', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%',
#        'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PTS'],
#       dtype='object')

# %%
merge_data = df.groupby('Player').agg({col:'max' for col in df.columns})
merge_data = merge_data.drop(['Player','Pos','Tm'], axis=1)

merge_data = merge_data.loc[:, ~merge_data.columns.str.contains('^Unnamed')]
merge_data = merge_data.rename(columns={'3P':'P3','3P%':'P3%','2P':'P2','2P%':'P2%','2PA':'P2A'})
# merge_data.columns

# %% [markdown]
# ### I got a 634 column record and 29 feature dataset.

# %%
print(merge_data.shape)
merge_data.head()
# Out:
# (634, 28)
#                    Salary Position   Age     G    GS      MP     FG    FGA  \
# Player
# Aaron Gordon   19863636.0       PF  24.0  58.0  58.0  1914.0  314.0  726.0
# Aaron Holiday   2329200.0       PG  23.0  58.0  26.0  1368.0  202.0  496.0
# Aaron Jackson   1378242.0        F   NaN   NaN   NaN     NaN    NaN    NaN
# Abdel Nader     1618520.0       SF  26.0  48.0   5.0   756.0  100.0  220.0
# Adam Mokoka           NaN      NaN  21.0  11.0   0.0   112.0   12.0   28.0
#
#                  FG%    P3  ...    FT%    ORB    DRB    TRB    AST   STL  \
# Player                      ...
# Aaron Gordon   0.433  68.0  ...  0.675  103.0  338.0  441.0  215.0  50.0
# Aaron Holiday  0.407  80.0  ...  0.861   21.0  111.0  132.0  193.0  45.0
# Aaron Jackson    NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN   NaN
# Abdel Nader    0.455  39.0  ...  0.774   14.0   76.0   90.0   35.0  20.0
# Adam Mokoka    0.429   6.0  ...  0.500    7.0    3.0   10.0    4.0   4.0
#
#                 BLK   TOV     PF    PTS
# Player
# Aaron Gordon   36.0  94.0  116.0  833.0
# Aaron Holiday  13.0  75.0  102.0  546.0
# Aaron Jackson   NaN   NaN    NaN    NaN
# Abdel Nader    20.0  36.0   65.0  287.0
# Adam Mokoka     0.0   2.0   17.0   32.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### dataset Persistence

# %%
merge_data.to_csv("raw_players_salary.csv.gz", compression='gzip')

# %% [markdown]
# ## Wrangling

# %%
raw_players_salary = pd.read_csv("raw_players_salary.csv.gz")
print(raw_players_salary.shape)
raw_players_salary.head()
# Out:
# (634, 29)
#           Player      Salary Position   Age     G    GS      MP     FG    FGA  \
# 0   Aaron Gordon  19863636.0       PF  24.0  58.0  58.0  1914.0  314.0  726.0
# 1  Aaron Holiday   2329200.0       PG  23.0  58.0  26.0  1368.0  202.0  496.0
# 2  Aaron Jackson   1378242.0        F   NaN   NaN   NaN     NaN    NaN    NaN
# 3    Abdel Nader   1618520.0       SF  26.0  48.0   5.0   756.0  100.0  220.0
# 4    Adam Mokoka         NaN      NaN  21.0  11.0   0.0   112.0   12.0   28.0
#
#      FG%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV     PF  \
# 0  0.433  ...  0.675  103.0  338.0  441.0  215.0  50.0  36.0  94.0  116.0
# 1  0.407  ...  0.861   21.0  111.0  132.0  193.0  45.0  13.0  75.0  102.0
# 2    NaN  ...    NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN
# 3  0.455  ...  0.774   14.0   76.0   90.0   35.0  20.0  20.0  36.0   65.0
# 4  0.429  ...  0.500    7.0    3.0   10.0    4.0   4.0   0.0   2.0   17.0
#
#      PTS
# 0  833.0
# 1  546.0
# 2    NaN
# 3  287.0
# 4   32.0
#
# [5 rows x 29 columns]

# %%
raw_players_salary.columns
# Out:
# Index(['Player', 'Salary', 'Position', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', 'P3', '3PA', 'P3%', 'P2', 'P2A', 'P2%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ### The char map show missing value.

# %%
msno.matrix(raw_players_salary.sample(raw_players_salary.shape[0])) # check None value

# %% [markdown]
# # todo 对于缺失值处理

# %%
clear_players_salary = raw_players_salary.dropna()

# %%
# clear_players_salary_with_mean = raw_players_salary.fillna(df.mean())
# clear_players_salary = clear_players_salary_with_mean.fillna(0)
msno.matrix(clear_players_salary.sample(clear_players_salary.shape[0]))

# %%
clear_players_salary.shape
# Out:
# (634, 29)

# %% [markdown]
# ### There is no duplicate player in the dataset

# %%
clear_players_salary['Player'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### The statistics show that mean, max, min of each feature. We could get the information about players
# such as xxx and xxxx of players usually are xxx and xxx.

# %% [markdown]
# clear_players_salary.head()

# %%
clear_players_salary.describe()
# Out:
#              Salary         Age           G          GS           MP  \
# count  6.340000e+02  634.000000  634.000000  634.000000   634.000000
# mean   7.363501e+06   25.514560   39.224763   18.491568   896.472155
# std    7.959977e+06    3.648293   18.632081   20.504586   608.175727
# min    1.979330e+05   19.000000    1.000000    0.000000     1.000000
# 25%    1.620564e+06   23.000000   29.000000    1.000000   387.250000
# 50%    4.861624e+06   25.701923   36.395833   16.390224   825.011218
# 75%    7.959990e+06   27.000000   56.000000   25.750000  1338.000000
# max    4.023176e+07   43.000000   66.000000   65.000000  2243.000000
#
#                FG          FGA         FG%          P3         3PA  ...  \
# count  634.000000   634.000000  634.000000  634.000000  634.000000  ...
# mean   151.224035   329.125394    0.440751   37.160883  126.007219  ...
# std    128.184282   273.877291    0.113462   49.432891  121.218478  ...
# min      0.000000     0.000000    0.000000    0.000000    0.000000  ...
# 25%     51.750000   127.500000    0.412000    0.000000   23.000000  ...
# 50%    138.200321   301.687500    0.433071   14.000000  116.504808  ...
# 75%    209.000000   446.000000    0.473000   59.000000  165.250000  ...
# max    623.000000  1386.000000    1.000000  271.000000  769.000000  ...
#
#               FT%         ORB         DRB         TRB         AST         STL  \
# count  634.000000  634.000000  634.000000  634.000000  634.000000  634.000000
# mean     0.748585   37.526511  128.902269  166.428779   90.061696   28.436302
# std      0.136577   37.784150  106.882931  139.524550   94.866582   22.588948
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.723000   12.000000   52.000000   67.250000   27.000000   10.000000
# 50%      0.743014   34.540064  118.866987  153.407051   81.809295   26.330128
# 75%      0.822750   45.000000  175.000000  222.750000  101.000000   39.750000
# max      1.000000  250.000000  653.000000  869.000000  636.000000  115.000000
#
#               BLK         TOV          PF          PTS
# count  634.000000  634.000000  634.000000   634.000000
# mean    18.371269   51.460204   76.436787   412.830563
# std     21.058636   45.893283   49.733777   357.708467
# min      0.000000    0.000000    0.000000     0.000000
# 25%      5.000000   18.250000   38.000000   147.250000
# 50%     16.000000   47.256410   70.724359   377.546474
# 75%     21.000000   65.000000  110.000000   556.250000
# max    187.000000  289.000000  246.000000  2096.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ### The map shows salary of player has hug gap.

# %%
clear_players_salary['Salary'].plot() # salary

# %%
clear_players_salary.to_csv("clear_players_salary.csv.gz", compression='gzip')

# %%
clear_players_salary = pd.read_csv("clear_players_salary.csv.gz",index_col=0)
clear_players_salary.head()
# Out:
#           Player        Salary Position        Age          G         GS  \
# 0   Aaron Gordon  1.986364e+07       PF  24.000000  58.000000  58.000000
# 1  Aaron Holiday  2.329200e+06       PG  23.000000  58.000000  26.000000
# 2  Aaron Jackson  1.378242e+06        F  25.701923  36.395833  16.780449
# 3    Abdel Nader  1.618520e+06       SF  26.000000  48.000000   5.000000
# 4    Adam Mokoka  7.345982e+06        0  21.000000  11.000000   0.000000
#
#             MP          FG       FGA       FG%  ...       FT%         ORB  \
# 0  1914.000000  314.000000  726.0000  0.433000  ...  0.675000  103.000000
# 1  1368.000000  202.000000  496.0000  0.407000  ...  0.861000   21.000000
# 2   825.011218  138.200321  301.6875  0.433071  ...  0.743014   34.540064
# 3   756.000000  100.000000  220.0000  0.455000  ...  0.774000   14.000000
# 4   112.000000   12.000000   28.0000  0.429000  ...  0.500000    7.000000
#
#           DRB         TRB         AST        STL        BLK       TOV  \
# 0  338.000000  441.000000  215.000000  50.000000  36.000000  94.00000
# 1  111.000000  132.000000  193.000000  45.000000  13.000000  75.00000
# 2  118.866987  153.407051   81.809295  26.330128  17.044872  47.25641
# 3   76.000000   90.000000   35.000000  20.000000  20.000000  36.00000
# 4    3.000000   10.000000    4.000000   4.000000   0.000000   2.00000
#
#            PF         PTS
# 0  116.000000  833.000000
# 1  102.000000  546.000000
# 2   70.724359  377.546474
# 3   65.000000  287.000000
# 4   17.000000   32.000000
#
# [5 rows x 29 columns]

# %% [markdown]
# ### we can find the mean of salary is 7849734, however the max of salary is 40231758

# %%
print(clear_players_salary['Salary'].mean())
clear_players_salary['Salary'].max()
# Out:
# 7363500.895993329
# 40231758.0

# %% [markdown]
# ### top 10

# %%
top10 =  clear_players_salary.sort_values("Salary",ascending=False).head()

plt.figure(figsize=(12,6))

plt.bar(top10.Player,top10.Salary)
plt.ylabel("Salary")
plt.xlabel("Player")
plt.title("TOP 10 NBA Salary")
# plt.xticks(rotation=70)

plt.show()

# %%
### 各个位置球员人数统计

# %%
clear_players_salary['Position'].value_counts()
# Out:
#  SG    122
# 0      109
#  SF     94
#  PF     86
#  C      83
#  PG     80
#  G      38
#  F      22
# Name: Position, dtype: int64

# %% [markdown]
# ### Visualizing the distribution of the dataset and We could get the father information that the 大部分分布在 1000000 一下

# %%
plt.figure(figsize=(15, 8))
df = clear_players_salary.iloc[:, 4:].copy()


sns.set_style("whitegrid")
sns.boxplot(data=df[list(df.columns)])

# %%
#球员薪水的分布密度图
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))
clear_players_salary['Salary'].hist(bins = 20,
       histtype = 'bar',
       align = 'left',
       orientation = 'vertical',
       alpha=0.5,
       normed =True)
clear_players_salary['Salary'].plot(kind='kde',style='k--')
plt.xlabel('SALARY') #Absolute value(1e7):10000000.
# Out:
# /Users/Tommy/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:316: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)
# Text(0.5, 0, 'SALARY')

# %% [markdown]
# ### 在三千万薪水之上没有中锋和得分后卫，大前锋最多。这也符合联盟现状，得分后卫和中锋的相对凋零。
#
# ### （大前锋和中锋的平均工资较高，但大前锋的拿顶薪数量更多，也就是优质的PF在球队地位更高）
# PG 控球后位 （Point Guard）
# PF 大前锋（Power Forward）
# SF 小前锋（Small Forward）
# SG 得分后位（Shooting Guard）
# C  中锋 Center
#
# SF-PF 锋卫摇摆人  Swingman 人数少，要求技术较高。

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))
ax = sns.lmplot(x='Age', y='Salary', data=clear_players_salary, hue='Position', fit_reg=False, aspect=2,size=7, legend=False, scatter_kws={"s": 200})
ax.set(xlabel='AGE', ylabel='Salary',title="Salary by Position")
plt.legend(loc='upper right', title='Position')
# Out:
# /Users/Tommy/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
###

# %%
plt.figure(figsize=(10,6))
ax = sns.barplot(x="Position", y="Salary",data=clear_players_salary,capsize=.2)

# %%
### different postion has same view that most players get less 10milion

# %%
g = sns.FacetGrid(clear_players_salary, col="Position", height=6)
g.map(plt.hist, "Salary")

# %% [markdown]
# # Feature Selection

# %%
#各参数与薪资相关性分析

# %%
plt.figure(figsize=(25, 12))
sns.heatmap(clear_players_salary.corr(), annot=True, fmt=".2f", cmap=plt.cm.Greens)

# %%
clear_players_salary.columns
# len(clear_players_salary.columns)
# Out:
# Index(['Player', 'Salary', 'Position', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', 'P3', '3PA', 'P3%', 'P2', 'P2A', 'P2%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ### There are some many feature for the dataset. I select 12 features which has strong relvant with salary
#
#
#  'MP',Minutes Played Per Game 场均上场时间
# 'FG', Field Goal Per Game   场均投篮命中
# 'FGA', Field Goal Attempts Per Game 场均投篮出手次数
# '2PA',2-Point Field Goal Attempts Per Game 场均二分投篮出手次数 【2分球机会高于3分球】
# '2P' 2-Point Field Goals Per Game 场均二分投篮命中次数
# 'FT',	Free Throw  Per Game  罚球命中次数
# 'FTA' Free Throws Attempted per game 场均罚球次数
#  'DRB' Defensive Rebounds Per Game 场均防守篮板 【仅与 防守篮板有关。。。】
#  'AST' Assists Per Game 场均助攻 【助攻也很重要】
# 'TOV', turnovers Per Game	失误次数
#  PTS points per game  场均得分【这个最重要。。。0.63最高了】

# %%
# selected_df = clear_players_salary[['Salary','GS','MP','FG','3P','2P','FT','ORB','DRB','TOV','PF']]
selected_df = clear_players_salary[['Salary','MP','FG','FGA','P2A','P2','FT','FTA','DRB','AST','TOV','PTS']]
print(selected_df.shape)
selected_df.head()
# Out:
# (634, 12)
#          Salary           MP          FG       FGA    P2A     P2          FT  \
# 0  1.986364e+07  1914.000000  314.000000  726.0000  500.0  246.0  137.000000
# 1  2.329200e+06  1368.000000  202.000000  496.0000  293.0  122.0   62.000000
# 2  1.378242e+06   825.011218  138.200321  301.6875    0.0    0.0   59.626603
# 3  1.618520e+06   756.000000  100.000000  220.0000  115.0   61.0   48.000000
# 4  7.345982e+06   112.000000   12.000000   28.0000   13.0    6.0    2.000000
#
#           FTA         DRB         AST       TOV         PTS
# 0  203.000000  338.000000  215.000000  94.00000  833.000000
# 1   72.000000  111.000000  193.000000  75.00000  546.000000
# 2   77.464744  118.866987   81.809295  47.25641  377.546474
# 3   62.000000   76.000000   35.000000  36.00000  287.000000
# 4    4.000000    3.000000    4.000000   2.00000   32.000000

# %%
plt.figure(figsize=(25, 12))

sns.heatmap(selected_df.corr(), annot=True, fmt=".2f", cmap=plt.cm.Greens)

# %% [markdown]
# ### It is quite hard find the relevant between salay with others.

# %%
_ = pd.plotting.scatter_matrix(selected_df, alpha=1, figsize=(20, 15), diagonal='hist')

# %%
selected_df.cov()
# Out:
#               Salary            MP            FG           FGA           P2A  \
# Salary  6.336123e+13  1.640988e+09  4.395683e+08  9.167590e+08  6.723692e+08
# MP      1.640988e+09  3.698777e+05  7.136781e+04  1.535908e+05  9.834560e+04
# FG      4.395683e+08  7.136781e+04  1.643121e+04  3.461369e+04  2.334991e+04
# FGA     9.167590e+08  1.535908e+05  3.461369e+04  7.500877e+04  4.837825e+04
# P2A     6.723692e+08  9.834560e+04  2.334991e+04  4.837825e+04  4.104498e+04
# P2      3.569045e+08  5.130309e+04  1.233340e+04  2.494505e+04  2.167228e+04
# FT      2.721973e+08  3.375971e+04  8.293263e+03  1.755199e+04  1.201622e+04
# FTA     3.341922e+08  4.243401e+04  1.038946e+04  2.170820e+04  1.526191e+04
# DRB     3.177504e+08  5.343208e+04  1.109405e+04  2.223447e+04  1.617113e+04
# AST     3.034795e+08  4.375103e+04  9.573926e+03  2.090882e+04  1.385225e+04
# TOV     1.516632e+08  2.370474e+04  5.398860e+03  1.154788e+04  7.815224e+03
# PTS     1.256423e+09  1.978698e+05  4.549220e+04  9.695088e+04  6.347404e+04
#
#                   P2            FT           FTA           DRB           AST  \
# Salary  3.569045e+08  2.721973e+08  3.341922e+08  3.177504e+08  3.034795e+08
# MP      5.130309e+04  3.375971e+04  4.243401e+04  5.343208e+04  4.375103e+04
# FG      1.233340e+04  8.293263e+03  1.038946e+04  1.109405e+04  9.573926e+03
# FGA     2.494505e+04  1.755199e+04  2.170820e+04  2.223447e+04  2.090882e+04
# P2A     2.167228e+04  1.201622e+04  1.526191e+04  1.617113e+04  1.385225e+04
# P2      1.166744e+04  6.324399e+03  8.122375e+03  8.966881e+03  7.076371e+03
# FT      6.324399e+03  5.439820e+03  6.690571e+03  5.398356e+03  5.338402e+03
# FTA     8.122375e+03  6.690571e+03  8.408527e+03  7.164787e+03  6.565891e+03
# DRB     8.966881e+03  5.398356e+03  7.164787e+03  1.142396e+04  5.884501e+03
# AST     7.076371e+03  5.338402e+03  6.565891e+03  5.884501e+03  8.999668e+03
# TOV     4.074216e+03  2.975940e+03  3.733909e+03  3.696660e+03  3.884107e+03
# PTS     3.326829e+04  2.410035e+04  2.987106e+04  2.989756e+04  2.713506e+04
#
#                  TOV           PTS
# Salary  1.516632e+08  1.256423e+09
# MP      2.370474e+04  1.978698e+05
# FG      5.398860e+03  4.549220e+04
# FGA     1.154788e+04  9.695088e+04
# P2A     7.815224e+03  6.347404e+04
# P2      4.074216e+03  3.326829e+04
# FT      2.975940e+03  2.410035e+04
# FTA     3.733909e+03  2.987106e+04
# DRB     3.696660e+03  2.989756e+04
# AST     3.884107e+03  2.713506e+04
# TOV     2.106193e+03  1.517535e+04
# PTS     1.517535e+04  1.279553e+05

# %% [markdown]
# ### save the dataset for modeling

# %%
selected_df.to_csv("fmanual_feature_Select_players_salary.csv.gz", compression='gzip')

# %%
selected_df.head()
# Out:
#          Salary           MP          FG       FGA    P2A     P2          FT  \
# 0  1.986364e+07  1914.000000  314.000000  726.0000  500.0  246.0  137.000000
# 1  2.329200e+06  1368.000000  202.000000  496.0000  293.0  122.0   62.000000
# 2  1.378242e+06   825.011218  138.200321  301.6875    0.0    0.0   59.626603
# 3  1.618520e+06   756.000000  100.000000  220.0000  115.0   61.0   48.000000
# 4  7.345982e+06   112.000000   12.000000   28.0000   13.0    6.0    2.000000
#
#           FTA         DRB         AST       TOV         PTS
# 0  203.000000  338.000000  215.000000  94.00000  833.000000
# 1   72.000000  111.000000  193.000000  75.00000  546.000000
# 2   77.464744  118.866987   81.809295  47.25641  377.546474
# 3   62.000000   76.000000   35.000000  36.00000  287.000000
# 4    4.000000    3.000000    4.000000   2.00000   32.000000

# %%
# selected_df.astype

# %%
print(selected_df.isnull().any())
print(np.isnan(selected_df).any())
# Out:
# Salary    False
# MP        False
# FG        False
# FGA       False
# P2A       False
# P2        False
# FT        False
# FTA       False
# DRB       False
# AST       False
# TOV       False
# PTS       False
# dtype: bool
# Salary    False
# MP        False
# FG        False
# FGA       False
# P2A       False
# P2        False
# FT        False
# FTA       False
# DRB       False
# AST       False
# TOV       False
# PTS       False
# dtype: bool
